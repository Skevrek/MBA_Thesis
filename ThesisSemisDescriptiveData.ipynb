# %% [markdown]
# <a href="https://colab.research.google.com/github/Skevrek/MBA_Thesis/blob/main/ThesisSemisDescriptiveData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel("/content/drive/MyDrive/MBA/DataTables_Semis-Forecasting/data_raw.xlsx")

# %%
df.describe()
# Out:
#               PPI         GPR  Export_Semis  Import_Semis  Employees_Semis  \
# count  349.000000  349.000000    349.000000    349.000000       349.000000
# mean    72.696000   98.858144     80.414900     85.565903       462.136963
# std     16.169981   49.316146     25.585696     28.158200       107.404748
# min     53.800000   39.045624     59.000000     55.700000       359.500000
# 25%     58.100000   76.262329     61.400000     62.500000       371.000000
# 50%     66.200000   88.778923     67.300000     78.300000       432.400000
# 75%     87.100000  106.934784     96.500000     97.300000       546.900000
# max    105.500000  512.529724    142.300000    162.300000       714.500000
#
#        Export_NoSemis  Import_NoSemis   RIW_Semis  Export_CapitalGoods  \
# count      349.000000      349.000000  349.000000           349.000000
# mean        78.696848      115.724928    2.457907           109.223209
# std         33.520545       14.740061    0.927689             7.228810
# ...

# %%
df.skew()
# Out:
# <ipython-input-4-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# PPI                    0.533973
# GPR                    4.483224
# Export_Semis           1.171418
# Import_Semis           1.298956
# Employees_Semis        0.835429
# Export_NoSemis         1.036645
# Import_NoSemis         0.294579
# RIW_Semis              0.521230
# Export_CapitalGoods    0.165978
# IP_NoEnergy            0.272744
# dtype: float64

# %%
df1 = df.describe()

# %%
df2 = df.skew()
# Out:
# <ipython-input-6-cc5dbc91cd19>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2 = df.skew()

# %%
df1
# Out:
#               PPI         GPR  Export_Semis  Import_Semis  Employees_Semis  \
# count  349.000000  349.000000    349.000000    349.000000       349.000000
# mean    72.696000   98.858144     80.414900     85.565903       462.136963
# std     16.169981   49.316146     25.585696     28.158200       107.404748
# min     53.800000   39.045624     59.000000     55.700000       359.500000
# 25%     58.100000   76.262329     61.400000     62.500000       371.000000
# 50%     66.200000   88.778923     67.300000     78.300000       432.400000
# 75%     87.100000  106.934784     96.500000     97.300000       546.900000
# max    105.500000  512.529724    142.300000    162.300000       714.500000
#
#        Export_NoSemis  Import_NoSemis   RIW_Semis  Export_CapitalGoods  \
# count      349.000000      349.000000  349.000000           349.000000
# mean        78.696848      115.724928    2.457907           109.223209
# std         33.520545       14.740061    0.927689             7.228810
# ...

# %%
df2 = df2.to_frame()

# %%
transposed_df = df2.transpose()

# %%
transposed_df
# Out:
#         PPI       GPR  Export_Semis  Import_Semis  Employees_Semis  \
# 0  0.533973  4.483224      1.171418      1.298956         0.835429
#
#    Export_NoSemis  Import_NoSemis  RIW_Semis  Export_CapitalGoods  IP_NoEnergy
# 0        1.036645        0.294579    0.52123             0.165978     0.272744

# %%
transposed_df = transposed_df.rename(index={'0': 'skew'})

# %%
transposed_df.index = ["skew"]

# %%
combined_df = pd.concat([df1, transposed_df]).round(2)

# %%
combined_df
# Out:
#           PPI     GPR  Export_Semis  Import_Semis  Employees_Semis  \
# count  349.00  349.00        349.00        349.00           349.00
# mean    72.70   98.86         80.41         85.57           462.14
# std     16.17   49.32         25.59         28.16           107.40
# min     53.80   39.05         59.00         55.70           359.50
# 25%     58.10   76.26         61.40         62.50           371.00
# 50%     66.20   88.78         67.30         78.30           432.40
# 75%     87.10  106.93         96.50         97.30           546.90
# max    105.50  512.53        142.30        162.30           714.50
# skew     0.53    4.48          1.17          1.30             0.84
#
#        Export_NoSemis  Import_NoSemis  RIW_Semis  Export_CapitalGoods  \
# count          349.00          349.00     349.00               349.00
# mean            78.70          115.72       2.46               109.22
# std             33.52           14.74       0.93                 7.23
# ...

# %%
df_ln = pd.read_excel("/content/drive/MyDrive/MBA/DataTables_Semis-Forecasting/data_LNed.xlsx")

# %%
df_ln.describe()
# Out:
#               PPI         GPR  Export_Semis  Import_Semis  Employees_Semis  \
# count  349.000000  349.000000    349.000000    349.000000       349.000000
# mean     4.262578    4.520223      4.344035      4.402994         6.111110
# std      0.215938    0.353753      0.282898      0.294586         0.218135
# min      3.985273    3.664731      4.077537      4.019980         5.884714
# 25%      4.062166    4.334179      4.117410      4.135167         5.916202
# 50%      4.192680    4.486149      4.209160      4.360548         6.069351
# 75%      4.467057    4.672219      4.569543      4.577799         6.304266
# max      4.658711    6.239359      4.957938      5.089446         6.571583
#
#        Export_NoSemis  Import_NoSemis   RIW_Semis  Export_CapitalGoods  \
# count      349.000000      349.000000  349.000000           349.000000
# mean         4.285124        4.743224    0.829094             4.691208
# std          0.391892        0.126243    0.374990             0.066262
# ...

# %%
df_ln.skew()
# Out:
# <ipython-input-17-3aaafd80988c>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_ln.skew()
# PPI                    0.354199
# GPR                    1.117121
# Export_Semis           0.937155
# Import_Semis           0.750440
# Employees_Semis        0.666717
# Export_NoSemis         0.499467
# Import_NoSemis         0.185401
# RIW_Semis              0.136522
# Export_CapitalGoods   -0.078462
# IP_NoEnergy            0.140557
# dtype: float64

# %%
df_ln1 = df_ln.describe()

# %%
df_ln2 = df_ln.skew()
# Out:
# <ipython-input-19-7a22913ad59f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_ln2 = df_ln.skew()

# %%
df_ln2 = df_ln2.to_frame()

# %%
transposed_df_ln2= df_ln2.transpose()

# %%
transposed_df_ln2
# Out:
#         PPI       GPR  Export_Semis  Import_Semis  Employees_Semis  \
# 0  0.354199  1.117121      0.937155       0.75044         0.666717
#
#    Export_NoSemis  Import_NoSemis  RIW_Semis  Export_CapitalGoods  IP_NoEnergy
# 0        0.499467        0.185401   0.136522            -0.078462     0.140557

# %%
transposed_df_ln2 = transposed_df_ln2.rename(index={'0': 'skew'})

# %%
transposed_df_ln2.index = ["skew"]

# %%
combined_df2 = pd.concat([df_ln1, transposed_df_ln2]).round(2)

# %%
combined_df2
# Out:
#           PPI     GPR  Export_Semis  Import_Semis  Employees_Semis  \
# count  349.00  349.00        349.00        349.00           349.00
# mean     4.26    4.52          4.34          4.40             6.11
# std      0.22    0.35          0.28          0.29             0.22
# min      3.99    3.66          4.08          4.02             5.88
# 25%      4.06    4.33          4.12          4.14             5.92
# 50%      4.19    4.49          4.21          4.36             6.07
# 75%      4.47    4.67          4.57          4.58             6.30
# max      4.66    6.24          4.96          5.09             6.57
# skew     0.35    1.12          0.94          0.75             0.67
#
#        Export_NoSemis  Import_NoSemis  RIW_Semis  Export_CapitalGoods  \
# count          349.00          349.00     349.00               349.00
# mean             4.29            4.74       0.83                 4.69
# std              0.39            0.13       0.37                 0.07
# ...

# %%
from google.colab import data_table
combined_df
# Out:
#           PPI     GPR  Export_Semis  Import_Semis  Employees_Semis  \
# count  349.00  349.00        349.00        349.00           349.00
# mean    72.70   98.86         80.41         85.57           462.14
# std     16.17   49.32         25.59         28.16           107.40
# min     53.80   39.05         59.00         55.70           359.50
# 25%     58.10   76.26         61.40         62.50           371.00
# 50%     66.20   88.78         67.30         78.30           432.40
# 75%     87.10  106.93         96.50         97.30           546.90
# max    105.50  512.53        142.30        162.30           714.50
# skew     0.53    4.48          1.17          1.30             0.84
#
#        Export_NoSemis  Import_NoSemis  RIW_Semis  Export_CapitalGoods  \
# count          349.00          349.00     349.00               349.00
# mean            78.70          115.72       2.46               109.22
# std             33.52           14.74       0.93                 7.23
# ...

# %%
combined_df2
# Out:
#           PPI     GPR  Export_Semis  Import_Semis  Employees_Semis  \
# count  349.00  349.00        349.00        349.00           349.00
# mean     4.26    4.52          4.34          4.40             6.11
# std      0.22    0.35          0.28          0.29             0.22
# min      3.99    3.66          4.08          4.02             5.88
# 25%      4.06    4.33          4.12          4.14             5.92
# 50%      4.19    4.49          4.21          4.36             6.07
# 75%      4.47    4.67          4.57          4.58             6.30
# max      4.66    6.24          4.96          5.09             6.57
# skew     0.35    1.12          0.94          0.75             0.67
#
#        Export_NoSemis  Import_NoSemis  RIW_Semis  Export_CapitalGoods  \
# count          349.00          349.00     349.00               349.00
# mean             4.29            4.74       0.83                 4.69
# std              0.39            0.13       0.37                 0.07
# ...
